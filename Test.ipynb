# %%
# !nvidia-smi

from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/soccer-demo/videos
# !mkdir -p /content/drive/MyDrive/soccer-demo/weights
# !mkdir -p /content/drive/MyDrive/soccer-demo/output

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Sat Apr 25 11:30:27 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# @title
# 1. Mergem în rădăcina Colab și facem curat (ștergem fișierele întrerupte și vechi)
# %cd /content
# !rm -rf soccer-video-detection-ai-agent
# !rm -f keypoint_detect.pt osnet_model.pth.tar-100 player_detect.pt

# 2. Clonăm repository-ul curat, ignorând fișierele mari și stricate ale autorului
# !GIT_LFS_SKIP_SMUDGE=1 git clone https://github.com/whisdev/soccer-video-detection-ai-agent.git

# 3. Mergem în interiorul proiectului, în folderul de greutăți
# %cd /content/soccer-video-detection-ai-agent/
# !mkdir -p weights
# %cd weights

# 4. Descărcăm modelele bune direct cu numele corect (aici va dura un pic, ai răbdare să ajungă toate la 100%)
# !wget -O keypoint_detect.pt https://huggingface.co/Nikola7777/turbo2/resolve/main/keypoint_detect.pt
# !wget -O player_detect.pt https://huggingface.co/Nikola7777/turbo2/resolve/main/player_detect.pt
# !wget -O osnet_model.pth.tar-100 https://huggingface.co/Nikola7777/turbo2/resolve/main/osnet_model.pth.tar-100

# 5. Instalăm bibliotecile necesare din fișierul pe care mi l-ai arătat
# %cd /content/soccer-video-detection-ai-agent
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'soccer-video-detection-ai-agent'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 42 (delta 11), reused 37 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 27.44 KiB | 3.92 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# /content/soccer-video-detection-ai-agent
# /content/soccer-video-detection-ai-agent/weights
# --2026-04-25 11:30:42--  https://huggingface.co/Nikola7777/turbo2/resolve/main/keypoint_detect.pt
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.121, 13.35.202.97, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !ls -lh /content/soccer-video-detection-ai-agent/weights/
# Out:
# total 313M
# -rw-r--r-- 1 root root  725 Apr 25 11:30 hrnetv2_w48.yaml
# -rw-r--r-- 1 root root 253M Apr 25 11:30 keypoint_detect.pt
# -rw-r--r-- 1 root root  39M Apr 25 11:30 osnet_model.pth.tar-100
# -rw-r--r-- 1 root root  22M Apr 25 11:30 player_detect.pt

# %%
import os
import glob

# Caută automat folderul în /content/
folders = glob.glob('/content/soccer-video-detection*')

if folders:
    # Intră în primul folder găsit
    os.chdir(folders[0])
    print("✅ Succes! Directorul curent este:", os.getcwd())
else:
    print("❌ EROARE: Folderul nu a fost găsit. Verifică panoul din stânga.")
# Out:
# ✅ Succes! Directorul curent este: /content/soccer-video-detection-ai-agent

# %%
# %cd /content/soccer-video-detection-ai-agent
# Out:
# /content/soccer-video-detection-ai-agent

# %%
# !python scripts/run_video.py \
  --video "/content/drive/MyDrive/soccer-demo/videos/meci_test.mp4" \
  --output-dir "/content/drive/MyDrive/soccer-demo/output" \
  --batch-size 8 \
  --save-video \
  --save-json
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ BBox Model Loaded
# ✅ Team Classifier Loaded (OSNet)
# ✅ HRNet Keypoints Model Loaded
# ...
# Soccer Video Detection AI Agent
# ...
# Videos: 1, Output: /content/drive/MyDrive/soccer-demo/output
#
#
# ...
# VIDEO 1/1: meci_test.mp4
# ...
# Predicting Batch: 1/49
# Predicting Batch: 2/49
# Predicting Batch: 3/49
# Predicting Batch: 4/49
# Predicting Batch: 5/49
# Predicting Batch: 6/49
# Predicting Batch: 7/49
# Predicting Batch: 8/49
# Predicting Batch: 9/49
# Predicting Batch: 10/49
# Predicting Batch: 11/49
# Predicting Batch: 12/49
# Predicting Batch: 13/49
# Predicting Batch: 14/49
# Predicting Batch: 15/49
# Predicting Batch: 16/49
# Predicting Batch: 17/49
# Predicting Batch: 18/49
# ...

# %%
# !python scripts/run_video.py \
--video "/content/drive/MyDrive/soccer-demo/videos/vid3.mp4" \
--output-dir "/content/drive/MyDrive/soccer-demo/output" \
--batch-size 8 \
--save-video \
--save-json
# Out:
# python3: can't open file '/content/scripts/run_video.py': [Errno 2] No such file or directory

# %%
# !python scripts/run_video.py \
--video "/content/drive/MyDrive/soccer-demo/videos/vid3.mp4" \
--output-dir "/content/drive/MyDrive/soccer-demo/output" \
--batch-size 16 \
--save-video \
--save-json
# Out:
# ✅ BBox Model Loaded
# ✅ Team Classifier Loaded (OSNet)
# ✅ HRNet Keypoints Model Loaded
# ...
# Soccer Video Detection AI Agent
# ...
# Videos: 1, Output: /content/drive/MyDrive/soccer-demo/output
#
#
# ...
# VIDEO 1/1: vid3.mp4
# ...
# Predicting Batch: 1/32
# Predicting Batch: 2/32
# Predicting Batch: 3/32
# Predicting Batch: 4/32
# Predicting Batch: 5/32
# Predicting Batch: 6/32
# Predicting Batch: 7/32
# Predicting Batch: 8/32
# Predicting Batch: 9/32
# Predicting Batch: 10/32
# Predicting Batch: 11/32
# Predicting Batch: 12/32
# Predicting Batch: 13/32
# Predicting Batch: 14/32
# Predicting Batch: 15/32
# Predicting Batch: 16/32
# Predicting Batch: 17/32
# Predicting Batch: 18/32
# Predicting Batch: 19/32
# Predicting Batch: 20/32
# Predicting Batch: 21/32
# Predicting Batch: 22/32
# Predicting Batch: 23/32
# Predicting Batch: 24/32
# Predicting Batch: 25/32
# Predicting Batch: 26/32
# Predicting Batch: 27/32
# Predicting Batch: 28/32
# Predicting Batch: 29/32
# Predicting Batch: 30/32
# ...

# %%
# !cp /content/Test.ipynb /content/soccer-video-detection-ai-agent/
# Out:
# cp: cannot stat '/content/Test.ipynb': No such file or directory
